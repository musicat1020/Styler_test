# %%
import pymongo
from pymongo import MongoClient
from gridfs import *
import os
client = MongoClient("mongodb+srv://ncumis-styler:ncumis-styler@cluster0.hz6vb.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client['new_img']

# %%
#寫入img到DB

db = client['1']
dirs = 'D:/styler/img/NET/top'

files = os.listdir(dirs)
#遍歷圖片目錄集合
for file in files:
    if file.endswith('.jpg'):
    #圖片的全路徑
        print(file)
        filesname = dirs + '\\' + file
    #分割，爲了存儲圖片文件的格式和名稱
        f = file.split('.')
    #類似於創建文件
        datatmp = open(filesname, 'rb')
    #創建寫入流
        imgput = GridFS(db)
    #將數據寫入，文件類型和名稱通過前面的分割得到
        insertimg=imgput.put(datatmp,content_type=f[1],filename=f[0])
        datatmp.close()
print("js")
# Out:
# NET_00001.jpg
# NET_00002.jpg
# NET_00003.jpg
# NET_00004.jpg
# NET_00005.jpg
# NET_00006.jpg
# NET_00007.jpg
# NET_00008.jpg
# NET_00009.jpg
# NET_00010.jpg
# NET_00011.jpg
# NET_00012.jpg
# NET_00013.jpg
# NET_00014.jpg
# NET_00015.jpg
# NET_00016.jpg
# NET_00017.jpg
# NET_00018.jpg
# NET_00019.jpg
# NET_00020.jpg
# NET_00021.jpg
# NET_00022.jpg
# NET_00023.jpg
# NET_00024.jpg
# NET_00025.jpg
# NET_00026.jpg
# NET_00027.jpg
# NET_00028.jpg
# NET_00029.jpg
# NET_00030.jpg
# NET_00031.jpg
# NET_00032.jpg
# NET_00033.jpg
# NET_00034.jpg
# NET_00035.jpg
# NET_00036.jpg
# NET_00037.jpg
# NET_00038.jpg
# NET_00039.jpg
# NET_00040.jpg
# NET_00041.jpg
# NET_00042.jpg
# NET_00043.jpg
# NET_00044.jpg
# NET_00045.jpg
# NET_00046.jpg
# NET_00047.jpg
# NET_00048.jpg
# NET_00049.jpg
# NET_00050.jpg
# NET_00051.jpg
# NET_00052.jpg
# NET_00053.jpg
# NET_00054.jpg
# NET_00055.jpg
# NET_00056.jpg
# NET_00057.jpg
# NET_00058.jpg
# NET_00059.jpg
# NET_00060.jpg
# NET_00061.jpg
# NET_00062.jpg
# ...

# %%
#寫入JSON到DB

import json 

db = client['1']
col = db['1']

destination_dir = 'D:/styler/img/NET/top/'
DList = os.listdir(destination_dir)
for file in DList:
    if file.endswith('.json'):
#     print(file)
        with open(destination_dir+file,'r') as f: #, encoding='UTF-8'
            load_dict = json.load(f)
            print(load_dict)
            print('\n')
            x = col.insert_one(load_dict)
# Out:
# {'brand': 'NET', 'price': '359', 'product_name': '條紋反摺袖棉彈T恤', 'website_url': 'https://www.net-fashion.net/product/353438'}
#
#
# {'brand': 'NET', 'price': '359', 'product_name': '條紋反摺袖棉彈T恤', 'website_url': 'https://www.net-fashion.net/product/353438'}
#
#
# {'brand': 'NET', 'price': '259', 'product_name': '寬鬆預言印字T恤', 'website_url': 'https://www.net-fashion.net/product/355302'}
#
#
# {'brand': 'NET', 'price': '259', 'product_name': '寬鬆預言印字T恤', 'website_url': 'https://www.net-fashion.net/product/355302'}
#
#
# {'brand': 'NET', 'price': '259', 'product_name': '寬鬆預言印字T恤', 'website_url': 'https://www.net-fashion.net/product/355302'}
#
#
# {'brand': 'NET', 'price': '259', 'product_name': '寬鬆標語印字T恤', 'website_url': 'https://www.net-fashion.net/product/355322'}
#
#
# {'brand': 'NET', 'price': '259', 'product_name': '寬鬆標語印字T恤', 'website_url': 'https://www.net-fashion.net/product/355322'}
#
#
# ...
