# %%
from PIL import Image
from sklearn.cluster import KMeans
from collections import Counter
from matplotlib import pyplot as plt
import cv2
import os
import json

base_location = 'D:/Styler/Fademeet/outwear/'#放未切割圖片資料夾
image_location = 'D:/Styler/Fademeet/outwear_cut/'#放切割完圖片資料夾
#base_location = 'D:/Styler/Fademeet/outwear/'#放未切割圖片資料夾
#image_location = 'D:/Styler/Fademeet/outwear_cut/'#放切割完圖片資料夾
jList = os.listdir(base_location)
print(cv2.__version__)

for file in jList:
    
    if file.endswith(".jpg"):
        img = cv2.imread(os.path.join(base_location,file))
       # cv2.imshow("org", img)
        imgSize = img.shape #大小/尺寸
        pw = imgSize[1]      #图片的宽
        ph = imgSize[0]    #图片的高
    
    if file.endswith(".json"):
        with open(os.path.join(base_location,file) , 'r') as reader:
            jf = json.loads(reader.read())
        strjf = str(jf)
        maxi = strjf.count('Class') + 1
        for i in range (1,maxi):
            stri = str(i)
            # 裁切區域的 x 與 y 座標（左上角）
            x1 = int(jf["item"+stri]["Bounding box"][0]*pw)
           
            y1 = int(jf["item"+stri]["Bounding box"][1]*ph)

            # 長寬
            x2 = int(jf["item"+stri]["Bounding box"][2]*pw)

            y2 = int(jf["item"+stri]["Bounding box"][3]*ph)

            type = jf["item"+stri]["Class"]
            print(type)
            # 裁切圖片
            crop_img = img[y1:y2, x1:x2]
           # cv2.imshow("org", img)
            #cv2.imshow("cropped", crop_img)   
            if crop_img.size>0:
                cv2.waitKey(0)
                cv2.imwrite(image_location +file.split('.')[0]+'_'+type+'.jpg', crop_img)
# Out:
# 4.5.1
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# shorts
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# long sleeve outwear
# shorts
# long sleeve top
# shorts
# trousers
# long sleeve top
# trousers
# long sleeve top
# shorts
# short sleeve top
# short sleeve top
# skirt
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# trousers
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# skirt
# long sleeve top
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# skirt
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# skirt
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# long sleeve outwear
# shorts
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve top
# long sleeve outwear
# shorts
# long sleeve outwear
# shorts
# long sleeve top
# shorts
# long sleeve outwear
# shorts
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# long sleeve outwear
# skirt
# long sleeve outwear
# shorts
# shorts
# long sleeve outwear
# trousers
# long sleeve top
# shorts
# long sleeve top
# shorts
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# long sleeve outwear
# long sleeve outwear
# shorts
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# shorts
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# long sleeve top
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve top
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve dress
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# short sleeve outwear
# trousers
# long sleeve outwear
# long sleeve dress
# long sleeve outwear
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# long sleeve outwear
# shorts
# short sleeve outwear
# trousers
# short sleeve top
# trousers
# short sleeve outwear
# shorts
# trousers
# short sleeve outwear
# trousers
# long sleeve outwear
# trousers
# short sleeve outwear
# trousers
# short sleeve top
# trousers
# long sleeve top
# trousers
# short sleeve outwear
# trousers
# short sleeve outwear
# trousers
# short sleeve outwear
# shorts
# short sleeve top
# trousers
# short sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# long sleeve outwear
# shorts
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# shorts
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# short sleeve outwear
# long sleeve outwear
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve top
# shorts
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# trousers
# trousers
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# trousers
# long sleeve top
# trousers
# long sleeve outwear
# long sleeve outwear
# trousers
# trousers
# long sleeve top
# long sleeve outwear
# trousers
# trousers
# long sleeve outwear
