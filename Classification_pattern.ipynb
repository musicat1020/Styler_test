# %%
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.prediction import CustomVisionPredictionClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateBatch, ImageFileCreateEntry, Region
from msrest.authentication import ApiKeyCredentials
import time

# %%
# 為資源的 Azure 端點和訂用帳戶金鑰建立變數

ENDPOINT = "https://stylervision.cognitiveservices.azure.com/"
training_key = "d7fb9c199bdb4c76952c6cb56b862b47"
prediction_key = "afbc2a74d69247429481db68cb64be3d"
prediction_resource_id = "14bf462c-fe1a-47c2-a915-5cacdd27e7b1"

# %%
#驗證用戶端
credentials = ApiKeyCredentials(in_headers={"Training-key": training_key})
trainer = CustomVisionTrainingClient(ENDPOINT, credentials)
prediction_credentials = ApiKeyCredentials(in_headers={"Prediction-key": prediction_key})
predictor = CustomVisionPredictionClient(ENDPOINT, prediction_credentials)

# %%
#建立新的視覺專案
publish_iteration_name = "classifyModel"

credentials = ApiKeyCredentials(in_headers={"Training-key": training_key})
trainer = CustomVisionTrainingClient(ENDPOINT, credentials)

#Create a new project
print ("Creating project...")
project = trainer.create_project("style_test", "8784e5a2-fd70-4be9-81a0-57c912a403f3")
# project = trainer.create_project("test", "0732100f-1a38-4e49-a514-c9b44c697ab5")
# Out:
# Creating project...

# %%
#將標記新增至專案

cam_tag = trainer.create_tag(project.id, "cam")#迷彩
dot_tag = trainer.create_tag(project.id, "dot")#點點
stripe_tag = trainer.create_tag(project.id, "stripe")#條紋
floral_tag = trainer.create_tag(project.id, "floral")#碎花
lattice_tag = trainer.create_tag(project.id, "lattice")#方格
plain_tag = trainer.create_tag(project.id, "plain")#素色

# %%
import numpy as np
#上傳和標記影像
base_image_location = "D:/styler/"

print("Adding images...")

image_list = []
    
def upload():
#1~63
    for image_num in range(1, 64):  
        file_name = "d ({}).jpg".format(image_num)
        with open(base_image_location + "dot/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[dot_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('d complete')
        
    for image_num in range(1, 64):  #改range變數 增加上傳張數
        file_name = "p ({}).jpg".format(image_num)
        with open(base_image_location + "plain/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[plain_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('p complete')
    
    for image_num in range(1, 64):
        file_name = "f ({}).jpg".format(image_num)
        with open(base_image_location + "floral/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[floral_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                 print("Image status: ", image.status)
            image_list.clear()
            print('f complete')
        
    for image_num in range(1, 64):
        file_name = "l ({}).jpg".format(image_num)
        with open(base_image_location + "lattice/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[lattice_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('l complete')

    for image_num in range(1, 64):
        file_name = "s ({}).jpg".format(image_num)
        with open(base_image_location + "stripe/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[stripe_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('s complete')
        
    for image_num in range(1, 64):
        file_name = "c ({}).jpg".format(image_num)
        with open(base_image_location + "camouflage/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[cam_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('c complete')

upload()
# Out:
# Adding images...
# length 63
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# ...

# %%
import numpy as np
#上傳和標記影像
base_image_location = "D:/styler/"

print("Adding images...")

image_list = []
    
def upload():
#64~127   
    for image_num in range(64,128): 
        file_name = "d ({}).jpg".format(image_num)
        with open(base_image_location + "dot/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[dot_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('d complete')
        
    for image_num in range(64,128): 
        file_name = "p ({}).jpg".format(image_num)
        with open(base_image_location + "plain/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[plain_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('p complete')
    
    for image_num in range(64,128):
        file_name = "f ({}).jpg".format(image_num)
        with open(base_image_location + "floral/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[floral_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                 print("Image status: ", image.status)
            image_list.clear()
            print('f complete')
        
    for image_num in range(64,128):
        file_name = "l ({}).jpg".format(image_num)
        with open(base_image_location + "lattice/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[lattice_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('l complete')
        
    for image_num in range(64,128):
        file_name = "s ({}).jpg".format(image_num)
        with open(base_image_location + "stripe/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[stripe_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('s complete')
        
    for image_num in range(64,128):
        file_name = "c ({}).jpg".format(image_num)
        with open(base_image_location + "camouflage/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[cam_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('c complete')

upload()
# Out:
# Adding images...
# length 64
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# ...

# %%
import numpy as np
#上傳和標記影像
base_image_location = "D:/styler/"

print("Adding images...")

image_list = []
    
def upload():
# 192~255
#我漏了中間128~191
    for image_num in range(192,256):  
        file_name = "d ({}).jpg".format(image_num)
        with open(base_image_location + "dot/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[dot_tag.id]))
        length = np.size(image_list)
    if(length<=64):

            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('d complete')
        
    for image_num in range(192,256): 
        file_name = "p ({}).jpg".format(image_num)
        with open(base_image_location + "plain/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[plain_tag.id]))
        length = np.size(image_list)
    if(length<=64):

            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('p complete')
    
    for image_num in range(192,256):
        file_name = "f ({}).jpg".format(image_num)
        with open(base_image_location + "floral/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[floral_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                 print("Image status: ", image.status)
            image_list.clear()
            print('f complete')
        
    for image_num in range(192,256):
        file_name = "l ({}).jpg".format(image_num)
        with open(base_image_location + "lattice/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[lattice_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('l complete')

    for image_num in range(192,256):
        file_name = "s ({}).jpg".format(image_num)
        with open(base_image_location + "stripe/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[stripe_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('s complete')
            
    for image_num in range(192,256):
        file_name = "c ({}).jpg".format(image_num)
        with open(base_image_location + "camouflage/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[cam_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('c complete')

upload()
# Out:
# Adding images...
# length 64
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# ...

# %%
import numpy as np
#上傳和標記影像
base_image_location = "D:/styler/"

print("Adding images...")

image_list = []
    
def upload():
# 256~319    
    for image_num in range(256,320):  
        file_name = "d ({}).jpg".format(image_num)
        with open(base_image_location + "dot/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[dot_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('d complete')
        
    for image_num in range(256,320):  
        file_name = "p ({}).jpg".format(image_num)
        with open(base_image_location + "plain/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[plain_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('p complete')
    
    for image_num in range(256,320):
        file_name = "f ({}).jpg".format(image_num)
        with open(base_image_location + "floral/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[floral_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                 print("Image status: ", image.status)
            image_list.clear()
            print('f complete')
        
    for image_num in range(256,320):
        file_name = "l ({}).jpg".format(image_num)
        with open(base_image_location + "lattice/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[lattice_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('l complete')
        
    for image_num in range(256,320):
        file_name = "s ({}).jpg".format(image_num)
        with open(base_image_location + "stripe/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[stripe_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('s complete')
        
    for image_num in range(256,320):
        file_name = "c ({}).jpg".format(image_num)
        with open(base_image_location + "camouflage/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[cam_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('c complete')

upload()
# Out:
# Adding images...
# length 64
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# ...

# %%
import numpy as np
#上傳和標記影像
base_image_location = "D:/styler/"

print("Adding images...")

image_list = []
    
def upload():
# 320~383    
    for image_num in range(320,384):  
        file_name = "d ({}).jpg".format(image_num)
        with open(base_image_location + "dot/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[dot_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('d complete')
        
    for image_num in range(320,384):  
        file_name = "p ({}).jpg".format(image_num)
        with open(base_image_location + "plain/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[plain_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('p complete')
    
    for image_num in range(320,384):
        file_name = "f ({}).jpg".format(image_num)
        with open(base_image_location + "floral/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[floral_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                 print("Image status: ", image.status)
            image_list.clear()
            print('f complete')
        
    for image_num in range(320,384):
        file_name = "l ({}).jpg".format(image_num)
        with open(base_image_location + "lattice/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[lattice_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('l complete')
        
    for image_num in range(320,384):
        file_name = "s ({}).jpg".format(image_num)
        with open(base_image_location + "stripe/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[stripe_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('s complete')
        
    for image_num in range(320,384):
        file_name = "c ({}).jpg".format(image_num)
        with open(base_image_location + "camouflage/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[cam_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('c complete')

upload()
# Out:
# Adding images...
# length 64
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# ...

# %%
import numpy as np
#上傳和標記影像
base_image_location = "D:/styler/"

print("Adding images...")

image_list = []
    
def upload():
# 384~447   
    for image_num in range(384,448):  
        file_name = "d ({}).jpg".format(image_num)
        with open(base_image_location + "dot/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[dot_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('d complete')
        
    for image_num in range(384,448): 
        file_name = "p ({}).jpg".format(image_num)
        with open(base_image_location + "plain/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[plain_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('p complete')
    
    for image_num in range(384,448):
        file_name = "f ({}).jpg".format(image_num)
        with open(base_image_location + "floral/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[floral_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                 print("Image status: ", image.status)
            image_list.clear()
            print('f complete')
        
    for image_num in range(384,423):
        file_name = "l ({}).jpg".format(image_num)
        with open(base_image_location + "lattice/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[lattice_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('l complete')
        
    for image_num in range(384,438):
        file_name = "s ({}).jpg".format(image_num)
        with open(base_image_location + "stripe/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[stripe_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('s complete')
        
    for image_num in range(384,448):
        file_name = "c ({}).jpg".format(image_num)
        with open(base_image_location + "camouflage/" + file_name, "rb") as image_contents:
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[cam_tag.id]))
        length = np.size(image_list)
    if(length<=64):
            print("length",length)
            upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
            for image in upload_result.images:
                print("Image status: ", image.status)
            image_list.clear()
            print('c complete')
upload()
# Out:
# Adding images...
# length 64
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# Image status:  OKDuplicate
# ...

# %%
base_image_location = "D:/styler/"
#這部分是我發現素色上的張數太少 另外再上傳
print("Adding images...")

image_list = []


def p_upload():

    for image_num in range(1, 64):  
        file_name = "p ({}).jpg".format(image_num)
        with open(base_image_location + "plainn/" + file_name, "rb") as image_contents:     
            image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[plain_tag.id]))
            print(image_contents)
        length = np.size(image_list)
    if(length<=64):
        print("length",length)
        upload_result = trainer.create_images_from_files("8784e5a2-fd70-4be9-81a0-57c912a403f3", ImageFileCreateBatch(images=image_list))
        for image in upload_result.images:
            print("Image status: ", image.status)
        image_list.clear()
        print('p complete')
        
            
p_upload()
# Out:
# Adding images...
# <_io.BufferedReader name='D:/styler/plainn/p (1).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (2).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (3).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (4).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (5).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (6).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (7).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (8).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (9).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (10).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (11).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (12).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (13).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (14).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (15).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (16).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (17).jpg'>
# ...

# %%
# base_image_location = "D:/styler/"

# print("Adding images...")

# image_list = []


# def p_upload():

#     for image_num in range(64, 128):  #改range變數 增加上傳張數
#         file_name = "p ({}).jpg".format(image_num)
#         with open(base_image_location + "plainn/" + file_name, "rb") as image_contents:     
#             image_list.append(ImageFileCreateEntry(name=file_name, contents=image_contents.read(), tag_ids=[plain_tag.id]))
#             print(image_contents)
#         length = np.size(image_list)
# #         print('p')
#     if(length<=64):
# #         l = int((length/64) +1)
# #         for n in range(0,64*l):
#         print("length",length)
#         upload_result = trainer.create_images_from_files("e3e99f7e-ce7a-4512-ab71-1de5ff7b51dc", ImageFileCreateBatch(images=image_list))
#         for image in upload_result.images:
#             print("Image status: ", image.status)
#         image_list.clear()
#         print('p complete')
        
            
# p_upload()
# Out:
# Adding images...
# <_io.BufferedReader name='D:/styler/plainn/p (64).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (65).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (66).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (67).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (68).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (69).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (70).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (71).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (72).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (73).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (74).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (75).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (76).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (77).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (78).jpg'>
# <_io.BufferedReader name='D:/styler/plainn/p (79).jpg'>
# ...

# %%
# #為專案定型 最少要放五張圖
# print ("Training...")
# iteration = trainer.train_project("4ed01f35-bc76-423b-b6b4-e2fbb958c56c")
# while (iteration.status != "Completed"):
#     iteration = trainer.get_iteration("4ed01f35-bc76-423b-b6b4-e2fbb958c56c", "314e1190-db1b-4102-af38-5e1a83b727f0")
#     print ("Training status: " + iteration.status)
#     time.sleep(1)

# %%
# # 發佈目前的反覆項目   這部分還沒成功
# trainer.publish_iteration("4b5746c2-c63c-4367-be51-335d6378440d", "b58eda6d-9ccc-46bc-8f32-7d523d09898c", "TESTONE", "8f4b15f6-5895-4afe-93e2-c87116a788a7")
# print ("Done!")
