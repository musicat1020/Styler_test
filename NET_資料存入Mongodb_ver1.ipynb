# %%
#2021/04/21
#NET多頁爬取子分頁後存入MongoDB
# 以data = {"shop" : "NET","cloth_id" : cloth_id,"cloth_name" : cloth_name,"file_name" : fname ,"URL" : pictures['href']}存入

import requests #匯入函式庫
from bs4 import BeautifulSoup #大倉庫匯bs4入小倉庫BeautifulSoup
import shutil #檔案下載與儲存的函式庫
import os
import pymongo

#連線cloud.mongodb(雲端版 mongodb atlas)
#注意Jamie:2ngg6tmGJgQZHv7是<使用者名稱>:<密碼>
#cluster0是cluster;test是資料庫名稱
client = pymongo.MongoClient("mongodb+srv://Jamie:2ngg6tmGJgQZHv7@cluster0.hz6vb.mongodb.net/test?retryWrites=true&w=majority")
db = client.test
collection = db['train']

m = 1

for page in range(1,3):#2頁
    url = 'https://www.net-fashion.net/category/1466/x'
    url = url.replace('x',str(page))#前者替換為後者 page是每次迴圈提取資料 str是強制轉換為文字型態(以這個例子只跑1、2 兩次)
    res = requests.get(url)
    soup = BeautifulSoup(res.text,'html.parser')#解析爬回來的頁面資料 後者為解析模式

    for pictures in soup.select('.main_img>a'):
        res1 = requests.get(pictures['href'])
        print(pictures['href'])
        soup1 = BeautifulSoup(res1.text,'html.parser')#解析爬回來的頁面資料 後者為解析模式
    
    
        for sub_pictures in soup1.select('.html_block_detail>p>img'):
            
            fname = 'NET_新品上市_' + str(m) + '.jpg'#取得圖檔名稱
            print(fname)
            
            #爬取商品id
            soup_cloth_id = soup1.select('.product_detail_Right>div.product_detail_Right_number')
            cloth_id = str(soup_cloth_id).split('>')[3].split('<')[0]
            print(cloth_id)
            
            #爬取商品名稱
            soup_cloth_name = soup1.select('.product_detail_Right>div.product_detail_Right_title')
            cloth_name = str(soup_cloth_name).split('>')[1].split('<')[0].lstrip().rstrip()
            print(cloth_name)
            
            #以這個格式的json存入mongodb
            data = {"shop" : "NET","cloth_id" : cloth_id,"cloth_name" : cloth_name,"file_name" : fname ,"URL" : pictures['href']}
            result = collection.insert_one(data)
            print(result.inserted_id)
            
            m = m + 1
# Out:
# https://www.net-fashion.net/product/342501
# NET_新品上市_1.jpg
# 13847
# 風景相片印花長版T恤
# 60803e827b4c05f7e9fddafc
# NET_新品上市_2.jpg
# 13847
# 風景相片印花長版T恤
# 60803e827b4c05f7e9fddafd
# NET_新品上市_3.jpg
# 13847
# 風景相片印花長版T恤
# 60803e827b4c05f7e9fddafe
# https://www.net-fashion.net/product/342517
# NET_新品上市_4.jpg
# 13885
# 反派迪士尼角色印花T恤
# 60803e837b4c05f7e9fddaff
# NET_新品上市_5.jpg
# 13885
# 反派迪士尼角色印花T恤
# 60803e837b4c05f7e9fddb00
# NET_新品上市_6.jpg
# 13885
# 反派迪士尼角色印花T恤
# 60803e837b4c05f7e9fddb01
# https://www.net-fashion.net/product/339505
# NET_新品上市_7.jpg
# 13882
# 經典星際大戰印字T恤
# 60803e837b4c05f7e9fddb02
# NET_新品上市_8.jpg
# 13882
# 經典星際大戰印字T恤
# 60803e847b4c05f7e9fddb03
# NET_新品上市_9.jpg
# 13882
# 經典星際大戰印字T恤
# 60803e847b4c05f7e9fddb04
# https://www.net-fashion.net/product/342116
# NET_新品上市_10.jpg
# 13536
# 基本素面毛圈連帽外套
# 60803e847b4c05f7e9fddb05
# NET_新品上市_11.jpg
# 13536
# 基本素面毛圈連帽外套
# 60803e847b4c05f7e9fddb06
# NET_新品上市_12.jpg
# 13536
# 基本素面毛圈連帽外套
# 60803e847b4c05f7e9fddb07
# NET_新品上市_13.jpg
# 13536
# ...

# %%
#delete NET在MongoDB的資料

import requests #匯入函式庫
from bs4 import BeautifulSoup #大倉庫匯bs4入小倉庫BeautifulSoup
import shutil #檔案下載與儲存的函式庫
import os
import pymongo

client = pymongo.MongoClient("mongodb+srv://Jamie:2ngg6tmGJgQZHv7@cluster0.hz6vb.mongodb.net/test?retryWrites=true&w=majority")
db = client.test
collection = db['train']

m = 1

for page in range(1,2):#2頁
    url = 'https://www.net-fashion.net/category/1466/x'
    url = url.replace('x',str(page))#前者替換為後者 page是每次迴圈提取資料 str是強制轉換為文字型態(以這個例子只跑1、2 兩次)
    res = requests.get(url)
    soup = BeautifulSoup(res.text,'html.parser')#解析爬回來的頁面資料 後者為解析模式

    for pictures in soup.select('.main_img>a'):
        res1 = requests.get(pictures['href'])
        print(pictures['href'])
        soup1 = BeautifulSoup(res1.text,'html.parser')#解析爬回來的頁面資料 後者為解析模式
    
    
        for sub_pictures in soup1.select('.html_block_detail>p>img'):           
            fname = 'NET_新品上市_' + str(m) + '.jpg'#取得圖檔名稱
            print(fname)
            soup_cloth_id = soup1.select('.product_detail_Right>div.product_detail_Right_number')
            cloth_id = str(soup_cloth_id).split('>')[3].split('<')[0]
            print(cloth_id)
            soup_cloth_name = soup1.select('.product_detail_Right>div.product_detail_Right_title')
            cloth_name = str(soup_cloth_name).split('>')[1].split('<')[0]
            print(cloth_name)
  
            #delete
            result = collection.delete_one({"cloth_id" : cloth_id}) 
        
            m = m + 1
# Out:
# https://www.net-fashion.net/product/342501
# NET_新品上市_連mongodb_ver3/NET_新品上市_1.jpg
# 13847
#
# 風景相片印花長版T恤
#
# NET_新品上市_連mongodb_ver3/NET_新品上市_2.jpg
# 13847
#
# 風景相片印花長版T恤
#
# NET_新品上市_連mongodb_ver3/NET_新品上市_3.jpg
# 13847
#
# 風景相片印花長版T恤
#
# https://www.net-fashion.net/product/342517
# NET_新品上市_連mongodb_ver3/NET_新品上市_4.jpg
# 13885
#
# 反派迪士尼角色印花T恤
#
# NET_新品上市_連mongodb_ver3/NET_新品上市_5.jpg
# 13885
#
# 反派迪士尼角色印花T恤
#
# NET_新品上市_連mongodb_ver3/NET_新品上市_6.jpg
# 13885
#
# 反派迪士尼角色印花T恤
#
# https://www.net-fashion.net/product/339505
# NET_新品上市_連mongodb_ver3/NET_新品上市_7.jpg
# 13882
#
# 經典星際大戰印字T恤
#
# NET_新品上市_連mongodb_ver3/NET_新品上市_8.jpg
# 13882
#
# 經典星際大戰印字T恤
#
# NET_新品上市_連mongodb_ver3/NET_新品上市_9.jpg
# 13882
#
# 經典星際大戰印字T恤
#
# https://www.net-fashion.net/product/342116
# NET_新品上市_連mongodb_ver3/NET_新品上市_10.jpg
# 13536
#
# 基本素面毛圈連帽外套
#
# NET_新品上市_連mongodb_ver3/NET_新品上市_11.jpg
# 13536
#
# 基本素面毛圈連帽外套
#
# NET_新品上市_連mongodb_ver3/NET_新品上市_12.jpg
# 13536
#
# 基本素面毛圈連帽外套
#
# ...

# %%
#NET單頁爬取後存入MongoDB(無爬子分業)
import requests #匯入函式庫
from bs4 import BeautifulSoup #大倉庫匯bs4入小倉庫BeautifulSoup
import pymongo

client = pymongo.MongoClient("mongodb+srv://Jamie:2ngg6tmGJgQZHv7@cluster0.hz6vb.mongodb.net/test?retryWrites=true&w=majority")
db = client.test
collection = db['train']

url = "https://www.net-fashion.net/category/1466/1"#最新的頁面開始爬

res = requests.get(url)
soup = BeautifulSoup(res.text,'html.parser')#解析爬回來的頁面資料

for pic_info in soup.select('.main_name>a'):
        cloth_id = pic_info['onclick'].split(";")[1].split(",")[1].split(":")[1]
        cloth_name = pic_info['onclick'].split(";")[1].split(",")[2].split(":")[1].split("}")[0]
        print(cloth_id)
        print(cloth_name)
        data = {"shop" : "NET","cloth_id" : cloth_id,"cloth_name" : cloth_name}
        result = collection.insert_one(data)
        print(result.inserted_id)
# Out:
# '1384740103'
#  '風景相片印花長版T恤'
# 608011787b4c05f7e9fdd9e9
# '1388590003'
#  '反派迪士尼角色印花T恤'
# 608011797b4c05f7e9fdd9ea
# '1388290003'
#  '經典星際大戰印字T恤'
# 608011797b4c05f7e9fdd9eb
# '1353660503'
#  '基本素面毛圈連帽外套'
# 608011797b4c05f7e9fdd9ec
# '1376871003'
#  '滿版印花合身T恤'
# 608011797b4c05f7e9fdd9ed
# '1376571103'
#  '基本合身小圓領T恤'
# 608011797b4c05f7e9fdd9ee
# '1376051403'
#  '素色單口袋寬鬆T恤'
# 608011797b4c05f7e9fdd9ef
# '1369200203'
#  '基本素色合身背心'
# 608011797b4c05f7e9fdd9f0
# '1368880303'
#  '素面挖背背心'
# 608011797b4c05f7e9fdd9f1
# '1307290003'
#  'DRY彈性POLO衫'
# 608011797b4c05f7e9fdd9f2
# '1340072650'
#  '軟料連袖圓領上衣'
# 608011797b4c05f7e9fdd9f3
# '1275231403'
#  '羅紋V領多色T恤'
# 608011797b4c05f7e9fdd9f4
# '1350331403'
#  '基本彈力短袖POLO衫'
# 608011797b4c05f7e9fdd9f5
# '1376600403'
#  '基本合身滿版印花T恤'
# 608011797b4c05f7e9fdd9f6
# '1370010103'
#  '棉質印花背心'
# 608011797b4c05f7e9fdd9f7
# '1368202203'
#  '基本細肩帶V領背心'
# 608011797b4c05f7e9fdd9f8

# %%
#test html語法爬取
import requests #匯入函式庫
from bs4 import BeautifulSoup #大倉庫匯bs4入小倉庫BeautifulSoup
import pymongo

url = "https://www.net-fashion.net/product/342501"#最新的頁面開始爬

res = requests.get(url)
soup = BeautifulSoup(res.text,'html.parser')#解析爬回來的頁面資料

for pic_info in soup.select('.product_detail_Right>div.product_detail_Right_title'):
        print(str(pic_info).split('>')[1].split('<')[0].lstrip().rstrip())
        
for pic_info1 in soup.select('.product_detail_Right>div.product_detail_Right_number'):
        print(str(pic_info1).split('>')[3].split('<')[0])
# Out:
# 風景相片印花長版T恤
# 13847
